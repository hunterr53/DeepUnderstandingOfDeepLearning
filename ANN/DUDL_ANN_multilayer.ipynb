# %% [markdown]
# # COURSE: A deep understanding of deep learning
# ## SECTION: ANNs
# ### LECTURE: Multilayer ANNs
# #### TEACHER: Mike X Cohen, sincxpress.com
# ##### COURSE URL: udemy.com/course/deeplearning_x/?couponCode=202401

# %%
# import libraries
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np

# %%
# create data

nPerClust = 100
blur = 1

A = [  1,  3 ] # x,y center
B = [  1, -2 ]

# generate data
a = [ A[0]+np.random.randn(nPerClust)*blur , A[1]+np.random.randn(nPerClust)*blur ]
b = [ B[0]+np.random.randn(nPerClust)*blur , B[1]+np.random.randn(nPerClust)*blur ]

# true labels
labels_np = np.vstack((np.zeros((nPerClust,1)),np.ones((nPerClust,1))))

# concatanate into a matrix
data_np = np.hstack((a,b)).T

# convert to a pytorch tensor
data = torch.tensor(data_np).float()
labels = torch.tensor(labels_np).float()

# show the data
fig = plt.figure(figsize=(5,5))
plt.plot(data[np.where(labels==0)[0],0],data[np.where(labels==0)[0],1],'bs')
plt.plot(data[np.where(labels==1)[0],0],data[np.where(labels==1)[0],1],'ko')
plt.title('The qwerties!')
plt.xlabel('qwerty dimension 1')
plt.ylabel('qwerty dimension 2')
plt.show()

# %%
print(np.shape(data))
# [dataPoint, (x,y)]
print(np.shape(labels))
# Out:
# torch.Size([200, 2])
# torch.Size([200, 1])

# %% [markdown]
# # Functions to build and train the model

# %%
def createANNmodel(learningRate):

  # model architecture
  ANNclassify = nn.Sequential(
      nn.Linear(2,16),  # input layer
      nn.ReLU(),        # activation unit
      nn.Linear(16,1),  # hidden layer
      nn.ReLU(),        # activation unit
      nn.Linear(1,1),   # output unit
      nn.Sigmoid(),     # final activation unit
        )

  # loss function
  lossfun = nn.BCELoss() # but better to use BCEWithLogitsLoss

  # optimizer
  optimizer = torch.optim.SGD(ANNclassify.parameters(),lr=learningRate)

  # model output
  return ANNclassify,lossfun,optimizer

# %%
# a function that trains the model

# a fixed parameter
numepochs = 1000
counter = 0
def trainTheModel(ANNmodel):

  # initialize losses
  losses = torch.zeros(numepochs)

  # loop over epochs
  for epochi in range(numepochs):

    # forward pass
    yHat = ANNmodel(data)

    # compute loss
    loss = lossfun(yHat,labels)
    loss2 = 0
    for i, yhat in enumerate(yHat):
      loss2 += 0.5 * (yhat-labels[i])**2
    np.printoptions(threshold=10)
    print(loss)
    print(loss2/len(yHat))
    
    losses[epochi] = loss

    # backprop
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
  
  
  
  # final forward pass
  predictions = ANNmodel(data)
    
  # compute the predictions and report accuracy
  # NOTE: Wasn't this ">0" previously?!?!
  totalacc = 100*torch.mean(((predictions>.5) == labels).float())
  
  return losses,predictions,totalacc

# %% [markdown]
# # Test the new code by running it once

# %%
# create everything
ANNclassify,lossfun,optimizer = createANNmodel(.01)

# run it
losses,predictions,totalacc = trainTheModel(ANNclassify)

# report accuracy
print('Final accuracy: %g%%' %totalacc)


# show the losses
plt.plot(losses.detach(),'o',markerfacecolor='w',linewidth=.1)
plt.xlabel('Epoch'), plt.ylabel('Loss')
plt.show()
# Out:
# tensor(0.6941, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.1256], grad_fn=<DivBackward0>)
# tensor(0.6824, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.1229], grad_fn=<DivBackward0>)
# tensor(0.6706, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.1201], grad_fn=<DivBackward0>)
# tensor(0.6588, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.1173], grad_fn=<DivBackward0>)
# tensor(0.6474, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.1146], grad_fn=<DivBackward0>)
# tensor(0.6363, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.1119], grad_fn=<DivBackward0>)
# tensor(0.6253, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.1093], grad_fn=<DivBackward0>)
# tensor(0.6147, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.1067], grad_fn=<DivBackward0>)
# tensor(0.6046, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.1042], grad_fn=<DivBackward0>)
# tensor(0.5948, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.1018], grad_fn=<DivBackward0>)
# tensor(0.5852, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0994], grad_fn=<DivBackward0>)
# tensor(0.5760, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0972], grad_fn=<DivBackward0>)
# tensor(0.5671, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0950], grad_fn=<DivBackward0>)
# tensor(0.5584, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0929], grad_fn=<DivBackward0>)
# tensor(0.5501, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0908], grad_fn=<DivBackward0>)
# tensor(0.5419, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0888], grad_fn=<DivBackward0>)
# tensor(0.5340, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0868], grad_fn=<DivBackward0>)
# tensor(0.5263, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0850], grad_fn=<DivBackward0>)
# tensor(0.5189, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0832], grad_fn=<DivBackward0>)
# tensor(0.5117, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0814], grad_fn=<DivBackward0>)
# tensor(0.5047, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0797], grad_fn=<DivBackward0>)
# tensor(0.4980, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0781], grad_fn=<DivBackward0>)
# tensor(0.4914, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0765], grad_fn=<DivBackward0>)
# tensor(0.4850, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0750], grad_fn=<DivBackward0>)
# tensor(0.4789, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0735], grad_fn=<DivBackward0>)
# tensor(0.4729, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0721], grad_fn=<DivBackward0>)
# tensor(0.4670, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0708], grad_fn=<DivBackward0>)
# tensor(0.4614, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0695], grad_fn=<DivBackward0>)
# tensor(0.4559, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0682], grad_fn=<DivBackward0>)
# tensor(0.4506, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0670], grad_fn=<DivBackward0>)
# tensor(0.4455, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0658], grad_fn=<DivBackward0>)
# tensor(0.4405, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0647], grad_fn=<DivBackward0>)
# tensor(0.4357, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0636], grad_fn=<DivBackward0>)
# tensor(0.4310, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0626], grad_fn=<DivBackward0>)
# tensor(0.4264, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0616], grad_fn=<DivBackward0>)
# tensor(0.4220, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0606], grad_fn=<DivBackward0>)
# tensor(0.4177, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0597], grad_fn=<DivBackward0>)
# tensor(0.4136, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0588], grad_fn=<DivBackward0>)
# tensor(0.4095, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0579], grad_fn=<DivBackward0>)
# tensor(0.4056, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0571], grad_fn=<DivBackward0>)
# tensor(0.4018, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0563], grad_fn=<DivBackward0>)
# tensor(0.3981, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0555], grad_fn=<DivBackward0>)
# tensor(0.3945, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0548], grad_fn=<DivBackward0>)
# tensor(0.3910, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0541], grad_fn=<DivBackward0>)
# tensor(0.3876, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0534], grad_fn=<DivBackward0>)
# tensor(0.3843, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0528], grad_fn=<DivBackward0>)
# tensor(0.3811, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0521], grad_fn=<DivBackward0>)
# tensor(0.3780, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0515], grad_fn=<DivBackward0>)
# tensor(0.3750, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0509], grad_fn=<DivBackward0>)
# tensor(0.3720, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0504], grad_fn=<DivBackward0>)
# tensor(0.3692, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0498], grad_fn=<DivBackward0>)
# tensor(0.3664, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0493], grad_fn=<DivBackward0>)
# tensor(0.3637, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0488], grad_fn=<DivBackward0>)
# tensor(0.3610, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0483], grad_fn=<DivBackward0>)
# tensor(0.3585, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0478], grad_fn=<DivBackward0>)
# tensor(0.3560, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0473], grad_fn=<DivBackward0>)
# tensor(0.3535, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0469], grad_fn=<DivBackward0>)
# tensor(0.3512, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0465], grad_fn=<DivBackward0>)
# tensor(0.3489, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0461], grad_fn=<DivBackward0>)
# tensor(0.3466, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0457], grad_fn=<DivBackward0>)
# tensor(0.3444, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0453], grad_fn=<DivBackward0>)
# tensor(0.3423, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0449], grad_fn=<DivBackward0>)
# tensor(0.3402, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0445], grad_fn=<DivBackward0>)
# tensor(0.3381, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0442], grad_fn=<DivBackward0>)
# tensor(0.3361, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0438], grad_fn=<DivBackward0>)
# tensor(0.3342, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0435], grad_fn=<DivBackward0>)
# tensor(0.3323, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0432], grad_fn=<DivBackward0>)
# tensor(0.3304, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0429], grad_fn=<DivBackward0>)
# tensor(0.3286, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0426], grad_fn=<DivBackward0>)
# tensor(0.3269, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0423], grad_fn=<DivBackward0>)
# tensor(0.3251, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0420], grad_fn=<DivBackward0>)
# tensor(0.3234, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0417], grad_fn=<DivBackward0>)
# tensor(0.3218, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0414], grad_fn=<DivBackward0>)
# tensor(0.3201, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0412], grad_fn=<DivBackward0>)
# tensor(0.3186, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0409], grad_fn=<DivBackward0>)
# tensor(0.3170, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0407], grad_fn=<DivBackward0>)
# tensor(0.3155, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0404], grad_fn=<DivBackward0>)
# tensor(0.3140, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0402], grad_fn=<DivBackward0>)
# tensor(0.3126, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0400], grad_fn=<DivBackward0>)
# tensor(0.3111, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0398], grad_fn=<DivBackward0>)
# tensor(0.3098, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0395], grad_fn=<DivBackward0>)
# tensor(0.3084, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0393], grad_fn=<DivBackward0>)
# tensor(0.3071, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0391], grad_fn=<DivBackward0>)
# tensor(0.3057, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0389], grad_fn=<DivBackward0>)
# tensor(0.3045, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0387], grad_fn=<DivBackward0>)
# tensor(0.3032, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0385], grad_fn=<DivBackward0>)
# tensor(0.3020, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0384], grad_fn=<DivBackward0>)
# tensor(0.3008, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0382], grad_fn=<DivBackward0>)
# tensor(0.2996, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0380], grad_fn=<DivBackward0>)
# tensor(0.2984, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0378], grad_fn=<DivBackward0>)
# tensor(0.2973, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0377], grad_fn=<DivBackward0>)
# tensor(0.2962, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0375], grad_fn=<DivBackward0>)
# tensor(0.2951, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0373], grad_fn=<DivBackward0>)
# tensor(0.2940, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0372], grad_fn=<DivBackward0>)
# tensor(0.2929, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0370], grad_fn=<DivBackward0>)
# tensor(0.2919, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0369], grad_fn=<DivBackward0>)
# tensor(0.2909, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0367], grad_fn=<DivBackward0>)
# tensor(0.2898, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0366], grad_fn=<DivBackward0>)
# tensor(0.2889, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0364], grad_fn=<DivBackward0>)
# tensor(0.2879, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0363], grad_fn=<DivBackward0>)
# tensor(0.2869, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0362], grad_fn=<DivBackward0>)
# tensor(0.2860, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0360], grad_fn=<DivBackward0>)
# tensor(0.2851, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0359], grad_fn=<DivBackward0>)
# tensor(0.2842, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0358], grad_fn=<DivBackward0>)
# tensor(0.2833, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0356], grad_fn=<DivBackward0>)
# tensor(0.2824, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0355], grad_fn=<DivBackward0>)
# tensor(0.2815, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0354], grad_fn=<DivBackward0>)
# tensor(0.2806, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0353], grad_fn=<DivBackward0>)
# tensor(0.2798, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0352], grad_fn=<DivBackward0>)
# tensor(0.2790, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0350], grad_fn=<DivBackward0>)
# tensor(0.2782, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0349], grad_fn=<DivBackward0>)
# tensor(0.2773, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0348], grad_fn=<DivBackward0>)
# tensor(0.2765, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0347], grad_fn=<DivBackward0>)
# tensor(0.2758, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0346], grad_fn=<DivBackward0>)
# tensor(0.2750, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0345], grad_fn=<DivBackward0>)
# tensor(0.2742, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0344], grad_fn=<DivBackward0>)
# tensor(0.2735, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0343], grad_fn=<DivBackward0>)
# tensor(0.2727, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0342], grad_fn=<DivBackward0>)
# tensor(0.2720, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0341], grad_fn=<DivBackward0>)
# tensor(0.2713, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0340], grad_fn=<DivBackward0>)
# tensor(0.2706, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0339], grad_fn=<DivBackward0>)
# tensor(0.2698, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0338], grad_fn=<DivBackward0>)
# tensor(0.2691, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0337], grad_fn=<DivBackward0>)
# tensor(0.2685, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0336], grad_fn=<DivBackward0>)
# tensor(0.2678, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0335], grad_fn=<DivBackward0>)
# tensor(0.2671, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0334], grad_fn=<DivBackward0>)
# tensor(0.2664, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0333], grad_fn=<DivBackward0>)
# tensor(0.2658, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0332], grad_fn=<DivBackward0>)
# tensor(0.2651, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0331], grad_fn=<DivBackward0>)
# tensor(0.2645, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0330], grad_fn=<DivBackward0>)
# tensor(0.2639, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0329], grad_fn=<DivBackward0>)
# tensor(0.2632, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0329], grad_fn=<DivBackward0>)
# tensor(0.2626, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0328], grad_fn=<DivBackward0>)
# tensor(0.2620, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0327], grad_fn=<DivBackward0>)
# tensor(0.2614, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0326], grad_fn=<DivBackward0>)
# tensor(0.2608, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0325], grad_fn=<DivBackward0>)
# tensor(0.2602, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0324], grad_fn=<DivBackward0>)
# tensor(0.2596, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0324], grad_fn=<DivBackward0>)
# tensor(0.2590, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0323], grad_fn=<DivBackward0>)
# tensor(0.2584, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0322], grad_fn=<DivBackward0>)
# tensor(0.2579, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0321], grad_fn=<DivBackward0>)
# tensor(0.2573, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0321], grad_fn=<DivBackward0>)
# tensor(0.2568, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0320], grad_fn=<DivBackward0>)
# tensor(0.2562, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0319], grad_fn=<DivBackward0>)
# tensor(0.2557, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0318], grad_fn=<DivBackward0>)
# tensor(0.2551, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0318], grad_fn=<DivBackward0>)
# tensor(0.2546, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0317], grad_fn=<DivBackward0>)
# tensor(0.2541, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0316], grad_fn=<DivBackward0>)
# tensor(0.2536, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0315], grad_fn=<DivBackward0>)
# tensor(0.2531, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0315], grad_fn=<DivBackward0>)
# tensor(0.2526, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0314], grad_fn=<DivBackward0>)
# tensor(0.2521, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0313], grad_fn=<DivBackward0>)
# tensor(0.2516, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0313], grad_fn=<DivBackward0>)
# tensor(0.2511, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0312], grad_fn=<DivBackward0>)
# tensor(0.2506, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0311], grad_fn=<DivBackward0>)
# tensor(0.2501, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0311], grad_fn=<DivBackward0>)
# tensor(0.2496, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0310], grad_fn=<DivBackward0>)
# tensor(0.2491, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0309], grad_fn=<DivBackward0>)
# tensor(0.2487, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0309], grad_fn=<DivBackward0>)
# tensor(0.2482, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0308], grad_fn=<DivBackward0>)
# tensor(0.2477, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0307], grad_fn=<DivBackward0>)
# tensor(0.2473, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0307], grad_fn=<DivBackward0>)
# tensor(0.2468, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0306], grad_fn=<DivBackward0>)
# tensor(0.2464, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0305], grad_fn=<DivBackward0>)
# tensor(0.2459, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0305], grad_fn=<DivBackward0>)
# tensor(0.2455, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0304], grad_fn=<DivBackward0>)
# tensor(0.2450, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0304], grad_fn=<DivBackward0>)
# tensor(0.2446, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0303], grad_fn=<DivBackward0>)
# tensor(0.2442, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0302], grad_fn=<DivBackward0>)
# tensor(0.2437, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0302], grad_fn=<DivBackward0>)
# tensor(0.2433, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0301], grad_fn=<DivBackward0>)
# tensor(0.2429, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0301], grad_fn=<DivBackward0>)
# tensor(0.2425, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0300], grad_fn=<DivBackward0>)
# tensor(0.2420, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0299], grad_fn=<DivBackward0>)
# tensor(0.2416, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0299], grad_fn=<DivBackward0>)
# tensor(0.2412, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0298], grad_fn=<DivBackward0>)
# tensor(0.2408, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0298], grad_fn=<DivBackward0>)
# tensor(0.2404, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0297], grad_fn=<DivBackward0>)
# tensor(0.2400, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0297], grad_fn=<DivBackward0>)
# tensor(0.2396, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0296], grad_fn=<DivBackward0>)
# tensor(0.2392, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0296], grad_fn=<DivBackward0>)
# tensor(0.2388, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0295], grad_fn=<DivBackward0>)
# tensor(0.2384, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0294], grad_fn=<DivBackward0>)
# tensor(0.2380, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0294], grad_fn=<DivBackward0>)
# tensor(0.2376, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0293], grad_fn=<DivBackward0>)
# tensor(0.2373, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0293], grad_fn=<DivBackward0>)
# tensor(0.2369, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0292], grad_fn=<DivBackward0>)
# tensor(0.2365, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0292], grad_fn=<DivBackward0>)
# tensor(0.2361, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0291], grad_fn=<DivBackward0>)
# tensor(0.2358, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0291], grad_fn=<DivBackward0>)
# tensor(0.2354, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0290], grad_fn=<DivBackward0>)
# tensor(0.2350, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0290], grad_fn=<DivBackward0>)
# tensor(0.2346, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0289], grad_fn=<DivBackward0>)
# tensor(0.2343, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0289], grad_fn=<DivBackward0>)
# tensor(0.2339, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0288], grad_fn=<DivBackward0>)
# tensor(0.2336, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0287], grad_fn=<DivBackward0>)
# tensor(0.2332, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0287], grad_fn=<DivBackward0>)
# tensor(0.2328, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0286], grad_fn=<DivBackward0>)
# tensor(0.2325, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0286], grad_fn=<DivBackward0>)
# tensor(0.2321, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0285], grad_fn=<DivBackward0>)
# tensor(0.2318, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0285], grad_fn=<DivBackward0>)
# tensor(0.2314, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0284], grad_fn=<DivBackward0>)
# tensor(0.2311, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0284], grad_fn=<DivBackward0>)
# tensor(0.2307, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0283], grad_fn=<DivBackward0>)
# tensor(0.2304, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0283], grad_fn=<DivBackward0>)
# tensor(0.2301, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0282], grad_fn=<DivBackward0>)
# tensor(0.2297, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0282], grad_fn=<DivBackward0>)
# tensor(0.2294, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0281], grad_fn=<DivBackward0>)
# tensor(0.2290, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0281], grad_fn=<DivBackward0>)
# tensor(0.2287, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0280], grad_fn=<DivBackward0>)
# tensor(0.2284, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0280], grad_fn=<DivBackward0>)
# tensor(0.2281, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0279], grad_fn=<DivBackward0>)
# tensor(0.2277, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0279], grad_fn=<DivBackward0>)
# tensor(0.2274, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0278], grad_fn=<DivBackward0>)
# tensor(0.2271, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0278], grad_fn=<DivBackward0>)
# tensor(0.2267, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0278], grad_fn=<DivBackward0>)
# tensor(0.2264, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0277], grad_fn=<DivBackward0>)
# tensor(0.2261, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0277], grad_fn=<DivBackward0>)
# tensor(0.2258, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0276], grad_fn=<DivBackward0>)
# tensor(0.2255, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0276], grad_fn=<DivBackward0>)
# tensor(0.2252, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0275], grad_fn=<DivBackward0>)
# tensor(0.2248, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0275], grad_fn=<DivBackward0>)
# tensor(0.2245, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0274], grad_fn=<DivBackward0>)
# tensor(0.2242, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0274], grad_fn=<DivBackward0>)
# tensor(0.2239, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0273], grad_fn=<DivBackward0>)
# tensor(0.2236, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0273], grad_fn=<DivBackward0>)
# tensor(0.2233, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0272], grad_fn=<DivBackward0>)
# tensor(0.2230, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0272], grad_fn=<DivBackward0>)
# tensor(0.2227, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0271], grad_fn=<DivBackward0>)
# tensor(0.2224, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0271], grad_fn=<DivBackward0>)
# tensor(0.2221, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0271], grad_fn=<DivBackward0>)
# tensor(0.2218, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0270], grad_fn=<DivBackward0>)
# tensor(0.2215, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0270], grad_fn=<DivBackward0>)
# tensor(0.2212, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0269], grad_fn=<DivBackward0>)
# tensor(0.2209, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0269], grad_fn=<DivBackward0>)
# tensor(0.2206, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0268], grad_fn=<DivBackward0>)
# tensor(0.2203, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0268], grad_fn=<DivBackward0>)
# tensor(0.2200, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0267], grad_fn=<DivBackward0>)
# tensor(0.2197, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0267], grad_fn=<DivBackward0>)
# tensor(0.2194, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0266], grad_fn=<DivBackward0>)
# tensor(0.2191, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0266], grad_fn=<DivBackward0>)
# tensor(0.2188, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0266], grad_fn=<DivBackward0>)
# tensor(0.2185, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0265], grad_fn=<DivBackward0>)
# tensor(0.2182, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0265], grad_fn=<DivBackward0>)
# tensor(0.2179, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0264], grad_fn=<DivBackward0>)
# tensor(0.2176, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0264], grad_fn=<DivBackward0>)
# tensor(0.2174, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0263], grad_fn=<DivBackward0>)
# tensor(0.2171, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0263], grad_fn=<DivBackward0>)
# tensor(0.2168, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0262], grad_fn=<DivBackward0>)
# tensor(0.2165, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0262], grad_fn=<DivBackward0>)
# tensor(0.2162, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0262], grad_fn=<DivBackward0>)
# tensor(0.2159, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0261], grad_fn=<DivBackward0>)
# tensor(0.2157, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0261], grad_fn=<DivBackward0>)
# tensor(0.2154, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0260], grad_fn=<DivBackward0>)
# tensor(0.2151, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0260], grad_fn=<DivBackward0>)
# tensor(0.2149, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0259], grad_fn=<DivBackward0>)
# tensor(0.2146, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0259], grad_fn=<DivBackward0>)
# tensor(0.2143, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0259], grad_fn=<DivBackward0>)
# tensor(0.2141, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0258], grad_fn=<DivBackward0>)
# tensor(0.2138, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0258], grad_fn=<DivBackward0>)
# tensor(0.2135, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0257], grad_fn=<DivBackward0>)
# tensor(0.2133, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0257], grad_fn=<DivBackward0>)
# tensor(0.2130, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0257], grad_fn=<DivBackward0>)
# tensor(0.2127, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0256], grad_fn=<DivBackward0>)
# tensor(0.2125, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0256], grad_fn=<DivBackward0>)
# tensor(0.2122, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0255], grad_fn=<DivBackward0>)
# tensor(0.2119, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0255], grad_fn=<DivBackward0>)
# tensor(0.2117, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0255], grad_fn=<DivBackward0>)
# tensor(0.2114, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0254], grad_fn=<DivBackward0>)
# tensor(0.2112, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0254], grad_fn=<DivBackward0>)
# tensor(0.2109, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0253], grad_fn=<DivBackward0>)
# tensor(0.2107, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0253], grad_fn=<DivBackward0>)
# tensor(0.2104, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0253], grad_fn=<DivBackward0>)
# tensor(0.2101, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0252], grad_fn=<DivBackward0>)
# tensor(0.2099, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0252], grad_fn=<DivBackward0>)
# tensor(0.2096, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0251], grad_fn=<DivBackward0>)
# tensor(0.2094, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0251], grad_fn=<DivBackward0>)
# tensor(0.2091, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0251], grad_fn=<DivBackward0>)
# tensor(0.2089, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0250], grad_fn=<DivBackward0>)
# tensor(0.2086, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0250], grad_fn=<DivBackward0>)
# tensor(0.2084, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0249], grad_fn=<DivBackward0>)
# tensor(0.2081, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0249], grad_fn=<DivBackward0>)
# tensor(0.2079, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0249], grad_fn=<DivBackward0>)
# tensor(0.2076, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0248], grad_fn=<DivBackward0>)
# tensor(0.2074, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0248], grad_fn=<DivBackward0>)
# tensor(0.2071, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0248], grad_fn=<DivBackward0>)
# tensor(0.2069, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0247], grad_fn=<DivBackward0>)
# tensor(0.2067, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0247], grad_fn=<DivBackward0>)
# tensor(0.2064, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0246], grad_fn=<DivBackward0>)
# tensor(0.2062, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0246], grad_fn=<DivBackward0>)
# tensor(0.2059, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0246], grad_fn=<DivBackward0>)
# tensor(0.2057, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0245], grad_fn=<DivBackward0>)
# tensor(0.2054, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0245], grad_fn=<DivBackward0>)
# tensor(0.2052, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0244], grad_fn=<DivBackward0>)
# tensor(0.2050, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0244], grad_fn=<DivBackward0>)
# tensor(0.2047, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0244], grad_fn=<DivBackward0>)
# tensor(0.2045, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0243], grad_fn=<DivBackward0>)
# tensor(0.2043, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0243], grad_fn=<DivBackward0>)
# tensor(0.2040, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0243], grad_fn=<DivBackward0>)
# tensor(0.2038, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0242], grad_fn=<DivBackward0>)
# tensor(0.2035, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0242], grad_fn=<DivBackward0>)
# tensor(0.2033, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0241], grad_fn=<DivBackward0>)
# tensor(0.2031, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0241], grad_fn=<DivBackward0>)
# tensor(0.2028, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0241], grad_fn=<DivBackward0>)
# tensor(0.2026, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0240], grad_fn=<DivBackward0>)
# tensor(0.2024, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0240], grad_fn=<DivBackward0>)
# tensor(0.2021, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0240], grad_fn=<DivBackward0>)
# tensor(0.2019, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0239], grad_fn=<DivBackward0>)
# tensor(0.2017, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0239], grad_fn=<DivBackward0>)
# tensor(0.2015, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0238], grad_fn=<DivBackward0>)
# tensor(0.2012, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0238], grad_fn=<DivBackward0>)
# tensor(0.2010, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0238], grad_fn=<DivBackward0>)
# tensor(0.2008, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0237], grad_fn=<DivBackward0>)
# tensor(0.2005, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0237], grad_fn=<DivBackward0>)
# tensor(0.2003, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0237], grad_fn=<DivBackward0>)
# tensor(0.2001, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0236], grad_fn=<DivBackward0>)
# tensor(0.1999, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0236], grad_fn=<DivBackward0>)
# tensor(0.1996, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0236], grad_fn=<DivBackward0>)
# tensor(0.1994, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0235], grad_fn=<DivBackward0>)
# tensor(0.1992, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0235], grad_fn=<DivBackward0>)
# tensor(0.1990, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0234], grad_fn=<DivBackward0>)
# tensor(0.1987, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0234], grad_fn=<DivBackward0>)
# tensor(0.1985, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0234], grad_fn=<DivBackward0>)
# tensor(0.1983, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0233], grad_fn=<DivBackward0>)
# tensor(0.1981, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0233], grad_fn=<DivBackward0>)
# tensor(0.1978, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0233], grad_fn=<DivBackward0>)
# tensor(0.1976, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0232], grad_fn=<DivBackward0>)
# tensor(0.1974, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0232], grad_fn=<DivBackward0>)
# tensor(0.1972, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0232], grad_fn=<DivBackward0>)
# tensor(0.1970, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0231], grad_fn=<DivBackward0>)
# tensor(0.1967, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0231], grad_fn=<DivBackward0>)
# tensor(0.1965, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0231], grad_fn=<DivBackward0>)
# tensor(0.1963, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0230], grad_fn=<DivBackward0>)
# tensor(0.1961, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0230], grad_fn=<DivBackward0>)
# tensor(0.1959, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0230], grad_fn=<DivBackward0>)
# tensor(0.1957, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0229], grad_fn=<DivBackward0>)
# tensor(0.1954, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0229], grad_fn=<DivBackward0>)
# tensor(0.1952, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0228], grad_fn=<DivBackward0>)
# tensor(0.1950, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0228], grad_fn=<DivBackward0>)
# tensor(0.1948, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0228], grad_fn=<DivBackward0>)
# tensor(0.1946, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0227], grad_fn=<DivBackward0>)
# tensor(0.1944, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0227], grad_fn=<DivBackward0>)
# tensor(0.1942, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0227], grad_fn=<DivBackward0>)
# tensor(0.1940, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0226], grad_fn=<DivBackward0>)
# tensor(0.1937, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0226], grad_fn=<DivBackward0>)
# tensor(0.1935, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0226], grad_fn=<DivBackward0>)
# tensor(0.1933, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0225], grad_fn=<DivBackward0>)
# tensor(0.1931, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0225], grad_fn=<DivBackward0>)
# tensor(0.1929, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0225], grad_fn=<DivBackward0>)
# tensor(0.1927, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0224], grad_fn=<DivBackward0>)
# tensor(0.1925, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0224], grad_fn=<DivBackward0>)
# tensor(0.1923, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0224], grad_fn=<DivBackward0>)
# tensor(0.1921, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0223], grad_fn=<DivBackward0>)
# tensor(0.1919, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0223], grad_fn=<DivBackward0>)
# tensor(0.1917, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0223], grad_fn=<DivBackward0>)
# tensor(0.1915, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0222], grad_fn=<DivBackward0>)
# tensor(0.1913, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0222], grad_fn=<DivBackward0>)
# tensor(0.1911, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0222], grad_fn=<DivBackward0>)
# tensor(0.1909, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0221], grad_fn=<DivBackward0>)
# tensor(0.1907, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0221], grad_fn=<DivBackward0>)
# tensor(0.1905, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0221], grad_fn=<DivBackward0>)
# tensor(0.1903, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0220], grad_fn=<DivBackward0>)
# tensor(0.1901, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0220], grad_fn=<DivBackward0>)
# tensor(0.1899, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0220], grad_fn=<DivBackward0>)
# tensor(0.1897, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0220], grad_fn=<DivBackward0>)
# tensor(0.1895, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0219], grad_fn=<DivBackward0>)
# tensor(0.1893, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0219], grad_fn=<DivBackward0>)
# tensor(0.1891, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0219], grad_fn=<DivBackward0>)
# tensor(0.1889, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0218], grad_fn=<DivBackward0>)
# tensor(0.1887, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0218], grad_fn=<DivBackward0>)
# tensor(0.1885, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0218], grad_fn=<DivBackward0>)
# tensor(0.1883, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0217], grad_fn=<DivBackward0>)
# tensor(0.1881, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0217], grad_fn=<DivBackward0>)
# tensor(0.1880, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0217], grad_fn=<DivBackward0>)
# tensor(0.1878, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0216], grad_fn=<DivBackward0>)
# tensor(0.1876, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0216], grad_fn=<DivBackward0>)
# tensor(0.1874, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0216], grad_fn=<DivBackward0>)
# tensor(0.1872, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0215], grad_fn=<DivBackward0>)
# tensor(0.1870, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0215], grad_fn=<DivBackward0>)
# tensor(0.1868, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0215], grad_fn=<DivBackward0>)
# tensor(0.1866, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0215], grad_fn=<DivBackward0>)
# tensor(0.1864, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0214], grad_fn=<DivBackward0>)
# tensor(0.1862, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0214], grad_fn=<DivBackward0>)
# tensor(0.1860, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0214], grad_fn=<DivBackward0>)
# tensor(0.1859, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0213], grad_fn=<DivBackward0>)
# tensor(0.1857, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0213], grad_fn=<DivBackward0>)
# tensor(0.1855, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0213], grad_fn=<DivBackward0>)
# tensor(0.1853, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0212], grad_fn=<DivBackward0>)
# tensor(0.1851, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0212], grad_fn=<DivBackward0>)
# tensor(0.1849, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0212], grad_fn=<DivBackward0>)
# tensor(0.1847, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0212], grad_fn=<DivBackward0>)
# tensor(0.1846, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0211], grad_fn=<DivBackward0>)
# tensor(0.1844, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0211], grad_fn=<DivBackward0>)
# tensor(0.1842, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0211], grad_fn=<DivBackward0>)
# tensor(0.1840, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0210], grad_fn=<DivBackward0>)
# tensor(0.1838, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0210], grad_fn=<DivBackward0>)
# tensor(0.1836, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0210], grad_fn=<DivBackward0>)
# tensor(0.1835, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0209], grad_fn=<DivBackward0>)
# tensor(0.1833, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0209], grad_fn=<DivBackward0>)
# tensor(0.1831, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0209], grad_fn=<DivBackward0>)
# tensor(0.1829, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0209], grad_fn=<DivBackward0>)
# tensor(0.1827, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0208], grad_fn=<DivBackward0>)
# tensor(0.1825, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0208], grad_fn=<DivBackward0>)
# tensor(0.1824, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0208], grad_fn=<DivBackward0>)
# tensor(0.1822, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0207], grad_fn=<DivBackward0>)
# tensor(0.1820, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0207], grad_fn=<DivBackward0>)
# tensor(0.1818, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0207], grad_fn=<DivBackward0>)
# tensor(0.1816, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0206], grad_fn=<DivBackward0>)
# tensor(0.1815, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0206], grad_fn=<DivBackward0>)
# tensor(0.1813, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0206], grad_fn=<DivBackward0>)
# tensor(0.1811, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0206], grad_fn=<DivBackward0>)
# tensor(0.1809, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0205], grad_fn=<DivBackward0>)
# tensor(0.1807, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0205], grad_fn=<DivBackward0>)
# tensor(0.1806, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0205], grad_fn=<DivBackward0>)
# tensor(0.1804, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0204], grad_fn=<DivBackward0>)
# tensor(0.1802, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0204], grad_fn=<DivBackward0>)
# tensor(0.1800, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0204], grad_fn=<DivBackward0>)
# tensor(0.1799, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0204], grad_fn=<DivBackward0>)
# tensor(0.1797, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0203], grad_fn=<DivBackward0>)
# tensor(0.1795, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0203], grad_fn=<DivBackward0>)
# tensor(0.1793, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0203], grad_fn=<DivBackward0>)
# tensor(0.1792, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0202], grad_fn=<DivBackward0>)
# tensor(0.1790, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0202], grad_fn=<DivBackward0>)
# tensor(0.1788, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0202], grad_fn=<DivBackward0>)
# tensor(0.1787, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0202], grad_fn=<DivBackward0>)
# tensor(0.1785, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0201], grad_fn=<DivBackward0>)
# tensor(0.1783, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0201], grad_fn=<DivBackward0>)
# tensor(0.1782, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0201], grad_fn=<DivBackward0>)
# tensor(0.1780, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0201], grad_fn=<DivBackward0>)
# tensor(0.1778, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0200], grad_fn=<DivBackward0>)
# tensor(0.1776, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0200], grad_fn=<DivBackward0>)
# tensor(0.1775, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0200], grad_fn=<DivBackward0>)
# tensor(0.1773, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0199], grad_fn=<DivBackward0>)
# tensor(0.1771, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0199], grad_fn=<DivBackward0>)
# tensor(0.1770, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0199], grad_fn=<DivBackward0>)
# tensor(0.1768, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0199], grad_fn=<DivBackward0>)
# tensor(0.1766, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0198], grad_fn=<DivBackward0>)
# tensor(0.1765, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0198], grad_fn=<DivBackward0>)
# tensor(0.1763, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0198], grad_fn=<DivBackward0>)
# tensor(0.1761, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0198], grad_fn=<DivBackward0>)
# tensor(0.1760, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0197], grad_fn=<DivBackward0>)
# tensor(0.1758, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0197], grad_fn=<DivBackward0>)
# tensor(0.1756, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0197], grad_fn=<DivBackward0>)
# tensor(0.1755, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0197], grad_fn=<DivBackward0>)
# tensor(0.1753, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0196], grad_fn=<DivBackward0>)
# tensor(0.1751, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0196], grad_fn=<DivBackward0>)
# tensor(0.1750, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0196], grad_fn=<DivBackward0>)
# tensor(0.1748, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0195], grad_fn=<DivBackward0>)
# tensor(0.1747, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0195], grad_fn=<DivBackward0>)
# tensor(0.1745, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0195], grad_fn=<DivBackward0>)
# tensor(0.1743, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0195], grad_fn=<DivBackward0>)
# tensor(0.1742, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0194], grad_fn=<DivBackward0>)
# tensor(0.1740, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0194], grad_fn=<DivBackward0>)
# tensor(0.1738, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0194], grad_fn=<DivBackward0>)
# tensor(0.1737, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0194], grad_fn=<DivBackward0>)
# tensor(0.1735, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0193], grad_fn=<DivBackward0>)
# tensor(0.1734, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0193], grad_fn=<DivBackward0>)
# tensor(0.1732, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0193], grad_fn=<DivBackward0>)
# tensor(0.1730, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0193], grad_fn=<DivBackward0>)
# tensor(0.1729, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0192], grad_fn=<DivBackward0>)
# tensor(0.1727, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0192], grad_fn=<DivBackward0>)
# tensor(0.1726, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0192], grad_fn=<DivBackward0>)
# tensor(0.1724, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0192], grad_fn=<DivBackward0>)
# tensor(0.1722, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0191], grad_fn=<DivBackward0>)
# tensor(0.1721, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0191], grad_fn=<DivBackward0>)
# tensor(0.1719, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0191], grad_fn=<DivBackward0>)
# tensor(0.1718, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0191], grad_fn=<DivBackward0>)
# tensor(0.1716, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0190], grad_fn=<DivBackward0>)
# tensor(0.1714, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0190], grad_fn=<DivBackward0>)
# tensor(0.1713, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0190], grad_fn=<DivBackward0>)
# tensor(0.1711, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0190], grad_fn=<DivBackward0>)
# tensor(0.1710, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0189], grad_fn=<DivBackward0>)
# tensor(0.1708, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0189], grad_fn=<DivBackward0>)
# tensor(0.1707, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0189], grad_fn=<DivBackward0>)
# tensor(0.1705, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0189], grad_fn=<DivBackward0>)
# tensor(0.1703, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0188], grad_fn=<DivBackward0>)
# tensor(0.1702, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0188], grad_fn=<DivBackward0>)
# tensor(0.1700, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0188], grad_fn=<DivBackward0>)
# tensor(0.1699, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0188], grad_fn=<DivBackward0>)
# tensor(0.1697, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0187], grad_fn=<DivBackward0>)
# tensor(0.1696, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0187], grad_fn=<DivBackward0>)
# tensor(0.1694, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0187], grad_fn=<DivBackward0>)
# tensor(0.1693, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0187], grad_fn=<DivBackward0>)
# tensor(0.1691, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0186], grad_fn=<DivBackward0>)
# tensor(0.1690, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0186], grad_fn=<DivBackward0>)
# tensor(0.1688, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0186], grad_fn=<DivBackward0>)
# tensor(0.1686, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0186], grad_fn=<DivBackward0>)
# tensor(0.1685, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0185], grad_fn=<DivBackward0>)
# tensor(0.1683, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0185], grad_fn=<DivBackward0>)
# tensor(0.1682, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0185], grad_fn=<DivBackward0>)
# tensor(0.1680, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0185], grad_fn=<DivBackward0>)
# tensor(0.1679, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0184], grad_fn=<DivBackward0>)
# tensor(0.1677, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0184], grad_fn=<DivBackward0>)
# tensor(0.1676, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0184], grad_fn=<DivBackward0>)
# tensor(0.1674, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0184], grad_fn=<DivBackward0>)
# tensor(0.1673, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0183], grad_fn=<DivBackward0>)
# tensor(0.1671, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0183], grad_fn=<DivBackward0>)
# tensor(0.1670, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0183], grad_fn=<DivBackward0>)
# tensor(0.1668, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0183], grad_fn=<DivBackward0>)
# tensor(0.1667, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0182], grad_fn=<DivBackward0>)
# tensor(0.1665, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0182], grad_fn=<DivBackward0>)
# tensor(0.1664, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0182], grad_fn=<DivBackward0>)
# tensor(0.1662, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0182], grad_fn=<DivBackward0>)
# tensor(0.1661, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0181], grad_fn=<DivBackward0>)
# tensor(0.1659, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0181], grad_fn=<DivBackward0>)
# ...
# tensor(0.1640, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0178], grad_fn=<DivBackward0>)
# tensor(0.1639, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0178], grad_fn=<DivBackward0>)
# tensor(0.1637, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0178], grad_fn=<DivBackward0>)
# tensor(0.1636, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0177], grad_fn=<DivBackward0>)
# tensor(0.1635, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0177], grad_fn=<DivBackward0>)
# tensor(0.1633, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0177], grad_fn=<DivBackward0>)
# tensor(0.1632, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0177], grad_fn=<DivBackward0>)
# tensor(0.1630, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0176], grad_fn=<DivBackward0>)
# tensor(0.1629, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0176], grad_fn=<DivBackward0>)
# tensor(0.1627, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0176], grad_fn=<DivBackward0>)
# tensor(0.1626, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0176], grad_fn=<DivBackward0>)
# tensor(0.1625, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0176], grad_fn=<DivBackward0>)
# tensor(0.1623, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0175], grad_fn=<DivBackward0>)
# tensor(0.1622, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0175], grad_fn=<DivBackward0>)
# tensor(0.1620, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0175], grad_fn=<DivBackward0>)
# tensor(0.1619, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0175], grad_fn=<DivBackward0>)
# tensor(0.1617, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0174], grad_fn=<DivBackward0>)
# tensor(0.1616, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0174], grad_fn=<DivBackward0>)
# tensor(0.1615, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0174], grad_fn=<DivBackward0>)
# tensor(0.1613, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0174], grad_fn=<DivBackward0>)
# tensor(0.1612, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0174], grad_fn=<DivBackward0>)
# tensor(0.1610, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0173], grad_fn=<DivBackward0>)
# tensor(0.1609, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0173], grad_fn=<DivBackward0>)
# tensor(0.1608, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0173], grad_fn=<DivBackward0>)
# tensor(0.1606, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0173], grad_fn=<DivBackward0>)
# tensor(0.1605, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0172], grad_fn=<DivBackward0>)
# tensor(0.1603, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0172], grad_fn=<DivBackward0>)
# tensor(0.1602, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0172], grad_fn=<DivBackward0>)
# tensor(0.1601, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0172], grad_fn=<DivBackward0>)
# tensor(0.1599, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0172], grad_fn=<DivBackward0>)
# tensor(0.1598, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0171], grad_fn=<DivBackward0>)
# tensor(0.1596, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0171], grad_fn=<DivBackward0>)
# tensor(0.1595, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0171], grad_fn=<DivBackward0>)
# tensor(0.1594, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0171], grad_fn=<DivBackward0>)
# tensor(0.1592, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0170], grad_fn=<DivBackward0>)
# tensor(0.1591, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0170], grad_fn=<DivBackward0>)
# tensor(0.1590, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0170], grad_fn=<DivBackward0>)
# tensor(0.1588, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0170], grad_fn=<DivBackward0>)
# tensor(0.1587, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0170], grad_fn=<DivBackward0>)
# tensor(0.1586, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0169], grad_fn=<DivBackward0>)
# tensor(0.1584, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0169], grad_fn=<DivBackward0>)
# tensor(0.1583, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0169], grad_fn=<DivBackward0>)
# tensor(0.1581, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0169], grad_fn=<DivBackward0>)
# tensor(0.1580, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0168], grad_fn=<DivBackward0>)
# tensor(0.1579, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0168], grad_fn=<DivBackward0>)
# tensor(0.1577, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0168], grad_fn=<DivBackward0>)
# tensor(0.1576, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0168], grad_fn=<DivBackward0>)
# tensor(0.1575, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0168], grad_fn=<DivBackward0>)
# tensor(0.1573, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0167], grad_fn=<DivBackward0>)
# tensor(0.1572, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0167], grad_fn=<DivBackward0>)
# tensor(0.1571, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0167], grad_fn=<DivBackward0>)
# tensor(0.1569, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0167], grad_fn=<DivBackward0>)
# tensor(0.1568, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0167], grad_fn=<DivBackward0>)
# tensor(0.1567, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0166], grad_fn=<DivBackward0>)
# tensor(0.1565, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0166], grad_fn=<DivBackward0>)
# tensor(0.1564, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0166], grad_fn=<DivBackward0>)
# tensor(0.1563, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0166], grad_fn=<DivBackward0>)
# tensor(0.1561, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0165], grad_fn=<DivBackward0>)
# tensor(0.1560, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0165], grad_fn=<DivBackward0>)
# tensor(0.1559, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0165], grad_fn=<DivBackward0>)
# tensor(0.1557, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0165], grad_fn=<DivBackward0>)
# tensor(0.1556, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0165], grad_fn=<DivBackward0>)
# tensor(0.1555, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0164], grad_fn=<DivBackward0>)
# tensor(0.1553, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0164], grad_fn=<DivBackward0>)
# tensor(0.1552, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0164], grad_fn=<DivBackward0>)
# tensor(0.1551, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0164], grad_fn=<DivBackward0>)
# tensor(0.1550, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0164], grad_fn=<DivBackward0>)
# tensor(0.1548, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0163], grad_fn=<DivBackward0>)
# tensor(0.1547, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0163], grad_fn=<DivBackward0>)
# tensor(0.1546, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0163], grad_fn=<DivBackward0>)
# tensor(0.1544, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0163], grad_fn=<DivBackward0>)
# tensor(0.1543, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0163], grad_fn=<DivBackward0>)
# tensor(0.1542, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0162], grad_fn=<DivBackward0>)
# tensor(0.1540, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0162], grad_fn=<DivBackward0>)
# tensor(0.1539, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0162], grad_fn=<DivBackward0>)
# tensor(0.1538, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0162], grad_fn=<DivBackward0>)
# tensor(0.1537, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0162], grad_fn=<DivBackward0>)
# tensor(0.1535, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0161], grad_fn=<DivBackward0>)
# tensor(0.1534, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0161], grad_fn=<DivBackward0>)
# tensor(0.1533, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0161], grad_fn=<DivBackward0>)
# tensor(0.1532, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0161], grad_fn=<DivBackward0>)
# tensor(0.1530, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0161], grad_fn=<DivBackward0>)
# tensor(0.1529, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0160], grad_fn=<DivBackward0>)
# tensor(0.1528, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0160], grad_fn=<DivBackward0>)
# tensor(0.1526, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0160], grad_fn=<DivBackward0>)
# tensor(0.1525, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0160], grad_fn=<DivBackward0>)
# tensor(0.1524, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0160], grad_fn=<DivBackward0>)
# tensor(0.1523, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0159], grad_fn=<DivBackward0>)
# tensor(0.1521, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0159], grad_fn=<DivBackward0>)
# tensor(0.1520, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0159], grad_fn=<DivBackward0>)
# tensor(0.1519, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0159], grad_fn=<DivBackward0>)
# tensor(0.1518, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0159], grad_fn=<DivBackward0>)
# tensor(0.1516, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0158], grad_fn=<DivBackward0>)
# tensor(0.1515, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0158], grad_fn=<DivBackward0>)
# tensor(0.1514, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0158], grad_fn=<DivBackward0>)
# tensor(0.1513, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0158], grad_fn=<DivBackward0>)
# tensor(0.1511, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0158], grad_fn=<DivBackward0>)
# tensor(0.1510, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0157], grad_fn=<DivBackward0>)
# tensor(0.1509, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0157], grad_fn=<DivBackward0>)
# tensor(0.1508, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0157], grad_fn=<DivBackward0>)
# tensor(0.1506, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0157], grad_fn=<DivBackward0>)
# tensor(0.1505, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0157], grad_fn=<DivBackward0>)
# tensor(0.1504, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0156], grad_fn=<DivBackward0>)
# tensor(0.1503, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0156], grad_fn=<DivBackward0>)
# tensor(0.1501, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0156], grad_fn=<DivBackward0>)
# tensor(0.1500, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0156], grad_fn=<DivBackward0>)
# tensor(0.1499, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0156], grad_fn=<DivBackward0>)
# tensor(0.1498, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0155], grad_fn=<DivBackward0>)
# tensor(0.1497, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0155], grad_fn=<DivBackward0>)
# tensor(0.1495, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0155], grad_fn=<DivBackward0>)
# tensor(0.1494, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0155], grad_fn=<DivBackward0>)
# tensor(0.1493, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0155], grad_fn=<DivBackward0>)
# tensor(0.1492, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0154], grad_fn=<DivBackward0>)
# tensor(0.1490, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0154], grad_fn=<DivBackward0>)
# tensor(0.1489, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0154], grad_fn=<DivBackward0>)
# tensor(0.1488, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0154], grad_fn=<DivBackward0>)
# tensor(0.1487, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0154], grad_fn=<DivBackward0>)
# tensor(0.1486, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0154], grad_fn=<DivBackward0>)
# tensor(0.1484, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0153], grad_fn=<DivBackward0>)
# tensor(0.1483, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0153], grad_fn=<DivBackward0>)
# tensor(0.1482, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0153], grad_fn=<DivBackward0>)
# tensor(0.1481, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0153], grad_fn=<DivBackward0>)
# tensor(0.1480, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0153], grad_fn=<DivBackward0>)
# tensor(0.1479, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0152], grad_fn=<DivBackward0>)
# tensor(0.1477, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0152], grad_fn=<DivBackward0>)
# tensor(0.1476, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0152], grad_fn=<DivBackward0>)
# tensor(0.1475, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0152], grad_fn=<DivBackward0>)
# tensor(0.1474, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0152], grad_fn=<DivBackward0>)
# tensor(0.1473, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0152], grad_fn=<DivBackward0>)
# tensor(0.1472, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0151], grad_fn=<DivBackward0>)
# tensor(0.1470, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0151], grad_fn=<DivBackward0>)
# tensor(0.1469, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0151], grad_fn=<DivBackward0>)
# tensor(0.1468, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0151], grad_fn=<DivBackward0>)
# tensor(0.1467, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0151], grad_fn=<DivBackward0>)
# tensor(0.1466, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0150], grad_fn=<DivBackward0>)
# tensor(0.1465, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0150], grad_fn=<DivBackward0>)
# tensor(0.1463, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0150], grad_fn=<DivBackward0>)
# tensor(0.1462, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0150], grad_fn=<DivBackward0>)
# tensor(0.1461, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0150], grad_fn=<DivBackward0>)
# tensor(0.1460, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0150], grad_fn=<DivBackward0>)
# tensor(0.1459, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0149], grad_fn=<DivBackward0>)
# tensor(0.1458, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0149], grad_fn=<DivBackward0>)
# tensor(0.1456, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0149], grad_fn=<DivBackward0>)
# tensor(0.1455, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0149], grad_fn=<DivBackward0>)
# tensor(0.1454, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0149], grad_fn=<DivBackward0>)
# tensor(0.1453, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0149], grad_fn=<DivBackward0>)
# tensor(0.1452, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0148], grad_fn=<DivBackward0>)
# tensor(0.1451, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0148], grad_fn=<DivBackward0>)
# tensor(0.1450, grad_fn=<BinaryCrossEntropyBackward0>)
# tensor([0.0148], grad_fn=<DivBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[92], line 5
#       2 ANNclassify,lossfun,optimizer = createANNmodel(.01)
#       4 # run it
# ----> 5 losses,predictions,totalacc = trainTheModel(ANNclassify)
#       7 # report accuracy
#       8 print('Final accuracy: %g%%' %totalacc)
#
# Cell In[91], line 29, in trainTheModel(ANNmodel)
#      26 losses[epochi] = loss
#      28 # backprop
# ---> 29 optimizer.zero_grad()
#      30 loss.backward()
#      31 optimizer.step()
#
# File c:\ProgramData\Anaconda3\Lib\site-packages\torch\_compile.py:24, in _disable_dynamo.<locals>.inner(*args, **kwargs)
#      20 @functools.wraps(fn)
#      21 def inner(*args, **kwargs):
#      22     import torch._dynamo
# ---> 24     return torch._dynamo.disable(fn, recursive)(*args, **kwargs)
#
# File c:\ProgramData\Anaconda3\Lib\site-packages\torch\_dynamo\decorators.py:50, in disable(fn, recursive)
#      48         fn = innermost_fn(fn)
#      49         assert callable(fn)
# ---> 50         return DisableContext()(fn)
#      51     return DisableContext()
#      52 else:
#
# File c:\ProgramData\Anaconda3\Lib\site-packages\torch\_dynamo\eval_frame.py:406, in _TorchDynamoContext.__call__(self, fn)
#     403 assert callable(fn)
#     405 try:
# --> 406     filename = inspect.getsourcefile(fn)
#     407 except TypeError:
#     408     filename = None
#
# File c:\ProgramData\Anaconda3\Lib\inspect.py:949, in getsourcefile(object)
#     946 elif any(filename.endswith(s) for s in
#     947              importlib.machinery.EXTENSION_SUFFIXES):
#     948     return None
# --> 949 if os.path.exists(filename):
#     950     return filename
#     951 # only return a non-existent filename if the module has a PEP 302 loader
#
# File <frozen genericpath>:19, in exists(path)
#
# KeyboardInterrupt:

# %% [markdown]
# # Now for the real test (varying learning rates)

# %%
# learning rates
learningrates = np.linspace(.001,.1,50)

# initialize
accByLR = []
allLosses = np.zeros((len(learningrates),numepochs))


# the loop
for i,lr in enumerate(learningrates):
  
  # create and run the model
  ANNclassify,lossfun,optimizer = createANNmodel(lr)
  losses,predictions,totalacc = trainTheModel(ANNclassify)

  # store the results
  accByLR.append(totalacc)
  allLosses[i,:] = losses.detach()

# %%
# plot the results
fig,ax = plt.subplots(1,2,figsize=(16,4))

ax[0].plot(learningrates,accByLR,'s-')
ax[0].set_xlabel('Learning rate')
ax[0].set_ylabel('Accuracy')
ax[0].set_title('Accuracy by learning rate')

ax[1].plot(allLosses.T)
ax[1].set_title('Losses by learning rate')
ax[1].set_xlabel('Epoch number')
ax[1].set_ylabel('Loss')
plt.show()

# %%
accByLR
# Out:
# [tensor(97.),
#  tensor(99.),
#  tensor(98.5000),
#  tensor(99.5000),
#  tensor(50.),
#  tensor(99.),
#  tensor(99.),
#  tensor(100.),
#  tensor(99.),
#  tensor(50.),
#  tensor(99.),
#  tensor(99.5000),
#  tensor(50.),
#  tensor(100.),
#  tensor(100.),
#  tensor(100.),
#  tensor(100.),
#  tensor(100.),
#  tensor(100.),
#  tensor(100.),
#  tensor(50.),
#  tensor(50.),
#  tensor(100.),
#  tensor(100.),
#  tensor(100.),
#  tensor(100.),
#  tensor(100.),
#  tensor(100.),
#  tensor(50.),
#  tensor(50.),
#  tensor(100.),
#  tensor(100.),
#  tensor(50.),
#  tensor(100.),
#  tensor(100.),
#  tensor(100.),
#  tensor(100.),
#  tensor(50.),
#  tensor(100.),
#  tensor(50.),
#  tensor(100.),
#  tensor(100.),
#  tensor(100.),
#  tensor(100.),
#  tensor(100.),
#  tensor(100.),
#  tensor(100.),
#  tensor(100.),
#  tensor(50.),
#  tensor(100.)]

# %%
sum(torch.tensor(accByLR)>70)/len(accByLR)
# Out:
# tensor(0.7800)

# %% [markdown]
# # Additional explorations

# %%
# 1) The code creates a model with 16 hidden units. Notice where the two "16"s appear when constructing the model. 
#    Recreate the model using 32 hidden units. Does that help with the issue of models getting stuck in local minima?
# 
# 2) Adjust the code to create two hidden layers. The first hidden layer should have 16 hidden units and the second 
#    hidden layer shuold have 32 units. What needs to change in the code to make the numbers match to prevent coding errors?
#
